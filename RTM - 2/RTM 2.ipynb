# %% [markdown]
# # No. 1 Eksplorasi Pertanyaan Dasar (Studi Kasus: Breast Cancer Dataset)

# %%
import pandas as pd

# %%
df = pd.read_csv('breast-cancer.csv')

# %%
df
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    40-49   premeno      15-19       0-2       yes          3  right
# 1    50-59      ge40      15-19       0-2        no          1  right
# 2    50-59      ge40      35-39       0-2        no          2   left
# 3    40-49   premeno      35-39       0-2       yes          3  right
# 4    40-49   premeno      30-34       3-5       yes          2   left
# ..     ...       ...        ...       ...       ...        ...    ...
# 272  50-59      ge40      30-34       6-8       yes          2   left
# 273  50-59   premeno      25-29       3-5       yes          2   left
# 274  30-39   premeno      30-34       6-8       yes          2  right
# 275  50-59   premeno      15-19       0-2        no          2  right
# 276  50-59      ge40      40-44       0-2        no          3   left
#
#     breast-quad irradiat                 Class
# 0       left_up       no     recurrence-events
# ...

# %%
df.isnull().sum()
# Out:
# age            0
# menopause      0
# tumor-size     0
# inv-nodes      0
# node-caps      0
# deg-malig      0
# breast         0
# breast-quad    0
# irradiat       0
# Class          0
# dtype: int64

# %%
df['age'].value_counts() #umur dari penderita kanker payudara
# Out:
# 50-59    91
# 40-49    89
# 60-69    55
# 30-39    36
# 70-79     5
# 20-29     1
# Name: age, dtype: int64

# %%
df["menopause"].value_counts()
#menopause adalah proses masa berhentinya haid yang permanen akibat hilangnya aktivitas folikuler ovarium.
#premeno adalah perempuan pada umur 45 -55
#ge40 adalah perempuan pada
#lt40
# Out:
# premeno    149
# ge40       123
# lt40         5
# Name: menopause, dtype: int64

# %%
df['tumor-size'].value_counts()
#ukuran besarnya tumor
# Out:
# 30-34    57
# 25-29    51
# 20-24    48
# 15-19    29
# 10-14    28
# 40-44    22
# 35-39    19
# 0-4       8
# 50-54     8
# 5-9       4
# 45-49     3
# Name: tumor-size, dtype: int64

# %%
df['inv-nodes'].value_counts()
#ukuran benjolan di bagian utama payudara
#ukuran dari kelenjar getah bening yang terkandung di payudara
# Out:
# 0-2      209
# 3-5       34
# 6-8       17
# 9-11       7
# 15-17      6
# 12-14      3
# 24-26      1
# Name: inv-nodes, dtype: int64

# %%
#benjolan ada atau tidak di payudara
#caps - capsul
#
df["node-caps"].value_counts()
# Out:
# no     221
# yes     56
# Name: node-caps, dtype: int64

# %%
df["deg-malig"].value_counts()
#stadium kanker payudara
# Out:
# 2    129
# 3     82
# 1     66
# Name: deg-malig, dtype: int64

# %%
df["breast"].value_counts()
#kanker payudara nya di kiri apa kanan
# Out:
# left     145
# right    132
# Name: breast, dtype: int64

# %%
df["breast-quad"].value_counts()
#bagian payudaranya yang mana
# Out:
# left_low     106
# left_up       94
# right_up      33
# right_low     23
# central       21
# Name: breast-quad, dtype: int64

# %%
df["irradiat"].value_counts()
#
# Out:
# no     215
# yes     62
# Name: irradiat, dtype: int64

# %%
df["Class"].value_counts()
# Out:
# no-recurrence-events    196
# recurrence-events        81
# Name: Class, dtype: int64

# %%
data_1 = df.rename(columns={"age" : "Umur", "menopause"  : "Golongan Menopause", "tumor-size": "Ukuran Tumor", "inv-nodes" : "Inv-Nodes","node-caps" : "Node-Caps","deg-malig" : "Tingkat Keganasan","breast" : "Payudara","breast-quad" : "Kuadran Payudara","irradiat" : "Iradiasi","Class" : "Class"})

# %%
data_1
# Out:
#       Umur Golongan Menopause Ukuran Tumor Inv-Nodes Node-Caps  \
# 0    40-49            premeno        15-19       0-2       yes
# 1    50-59               ge40        15-19       0-2        no
# 2    50-59               ge40        35-39       0-2        no
# 3    40-49            premeno        35-39       0-2       yes
# 4    40-49            premeno        30-34       3-5       yes
# ..     ...                ...          ...       ...       ...
# 272  50-59               ge40        30-34       6-8       yes
# 273  50-59            premeno        25-29       3-5       yes
# 274  30-39            premeno        30-34       6-8       yes
# 275  50-59            premeno        15-19       0-2        no
# 276  50-59               ge40        40-44       0-2        no
#
#      Tingkat Keganasan Payudara Kuadran Payudara Iradiasi  \
# 0                    3    right          left_up       no
# 1                    1    right          central       no
# ...

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Umur                277 non-null    object
#  1   Golongan Menopause  277 non-null    object
#  2   Ukuran Tumor        277 non-null    object
#  3   Inv-Nodes           277 non-null    object
#  4   Node-Caps           277 non-null    object
#  5   Tingkat Keganasan   277 non-null    int64
#  6   Payudara            277 non-null    object
#  7   Kuadran Payudara    277 non-null    object
#  8   Iradiasi            277 non-null    object
#  9   Class               277 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 21.8+ KB

# %%
#Berapa banyak pasien yang berumur 50-59 tahun dengan derajat keganasan kanker payudara sebesar 2?
tingkat_ganas = ['2']
no_1_a = data_1[(data_1['Umur'] == '50-59') &
              data_1['Tingkat Keganasan'].isin(tingkat_ganas)]

# %%
no_1_a
# Out:
#       Umur Golongan Menopause Ukuran Tumor Inv-Nodes Node-Caps  \
# 2    50-59               ge40        35-39       0-2        no
# 5    50-59            premeno        25-29       3-5        no
# 10   50-59            premeno        25-29       0-2        no
# 13   50-59               ge40        25-29       0-2        no
# 18   50-59            premeno        40-44       0-2        no
# 21   50-59               ge40        15-19       0-2        no
# 24   50-59               ge40        20-24       3-5       yes
# 25   50-59               ge40        10-14       0-2        no
# 46   50-59            premeno        50-54       0-2       yes
# 64   50-59            premeno        50-54      9-11       yes
# 75   50-59               lt40        15-19       0-2        no
# 87   50-59            premeno        10-14       0-2        no
# 88   50-59               ge40        20-24       0-2        no
# 95   50-59            premeno        15-19       0-2        no
# ...

# %%
len(no_1_a)
# Out:
# 39

# %%
#Berapa banyak pasien dengan ukuran tumor 0-4 (mm) dengan kondisi kelenjar getah bening belum/tidak menembus kapsul dan sekitarnya (node-caps)?
node_caps = ['no']
no_1_b = data_1[(data_1['Ukuran Tumor'] == '0-4') &
              data_1['Node-Caps'].isin(node_caps)]

# %%
no_1_b
# Out:
#       Umur Golongan Menopause Ukuran Tumor Inv-Nodes Node-Caps  \
# 8    40-49            premeno          0-4       0-2        no
# 49   40-49            premeno          0-4       0-2        no
# 55   30-39            premeno          0-4       0-2        no
# 79   30-39            premeno          0-4       0-2        no
# 130  50-59               ge40          0-4       0-2        no
# 131  50-59               ge40          0-4       0-2        no
# 245  70-79               ge40          0-4       0-2        no
# 256  50-59               ge40          0-4       0-2        no
#
#      Tingkat Keganasan Payudara Kuadran Payudara Iradiasi  \
# 8                    2    right        right_low       no
# 49                   3     left          central       no
# 55                   2    right          central       no
# 79                   2    right          central       no
# 130                  1    right          central       no
# ...

# %%
len(no_1_b)
# Out:
# 8

# %%
#Berapa banyak pasien dengan tumor yang melakukan terapi radiasi dengan derajat keganasan kanker sebesar 2 dan 3?
tingkat_ganas_2 = ['2','3']
no_1_c = data_1[(data_1['Iradiasi'] == 'yes') &
              data_1['Tingkat Keganasan'].isin(tingkat_ganas_2)]
no_1_c
# Out:
#       Umur Golongan Menopause Ukuran Tumor Inv-Nodes Node-Caps  \
# 3    40-49            premeno        35-39       0-2       yes
# 5    50-59            premeno        25-29       3-5        no
# 9    40-49               ge40        40-44     15-17       yes
# 14   40-49            premeno        25-29       0-2        no
# 20   60-69               ge40        40-44       3-5        no
# 23   30-39            premeno        15-19       6-8       yes
# 39   40-49            premeno        35-39      9-11       yes
# 44   60-69               ge40        10-14       0-2        no
# 45   40-49            premeno        35-39       0-2       yes
# 46   50-59            premeno        50-54       0-2       yes
# 56   50-59               ge40        40-44       6-8       yes
# 57   40-49            premeno        30-34       0-2        no
# 66   50-59            premeno        25-29       3-5       yes
# 69   30-39            premeno        25-29       6-8       yes
# ...

# %%
len(no_1_c)
# Out:
# 58

# %%
#Berapa banyak pasien yang memiliki tumor yang terletak di sebelah kanan dan kiri serta tepatnya pada kuadran pusat?
letak = ['right','left']
no_1_d = data_1[(data_1['Kuadran Payudara'] == 'central') &
              data_1['Payudara'].isin(letak)]
no_1_d
# Out:
#       Umur Golongan Menopause Ukuran Tumor Inv-Nodes Node-Caps  \
# 1    50-59               ge40        15-19       0-2        no
# 12   50-59               ge40        30-34       0-2        no
# 15   30-39            premeno        20-24       0-2        no
# 29   60-69               ge40        30-34       0-2        no
# 35   60-69               ge40        45-49       6-8       yes
# 49   40-49            premeno          0-4       0-2        no
# 55   30-39            premeno          0-4       0-2        no
# 61   50-59               ge40        15-19       0-2        no
# 72   40-49            premeno        25-29       0-2        no
# 79   30-39            premeno          0-4       0-2        no
# 99   60-69               ge40        30-34       3-5       yes
# 108  60-69               ge40          5-9       0-2        no
# 130  50-59               ge40          0-4       0-2        no
# 133  50-59            premeno        30-34       0-2        no
# ...

# %%
len(no_1_d)
# Out:
# 21

# %%
#Berapa banyak pasien yang sedang premenopause dengan kelenjar getah bening yang mengandung kanker payudara pada range 6-8?
filter_e = ['6-8']
no_1_e = data_1[(data_1['Golongan Menopause'] == 'premeno') &
              data_1['Inv-Nodes'].isin(filter_e)]
no_1_e
# Out:
#       Umur Golongan Menopause Ukuran Tumor Inv-Nodes Node-Caps  \
# 23   30-39            premeno        15-19       6-8       yes
# 69   30-39            premeno        25-29       6-8       yes
# 82   30-39            premeno        25-29       6-8       yes
# 110  40-49            premeno        30-34       6-8       yes
# 154  40-49            premeno        30-34       6-8        no
# 264  40-49            premeno        20-24       6-8        no
# 274  30-39            premeno        30-34       6-8       yes
#
#      Tingkat Keganasan Payudara Kuadran Payudara Iradiasi  \
# 23                   3     left         left_low      yes
# 69                   3     left        right_low      yes
# 82                   2    right          left_up      yes
# 110                  3    right          left_up       no
# 154                  2     left          left_up       no
# 264                  2    right         left_low      yes
# ...

# %%
len(no_1_e)
# Out:
# 7

# %%
#Berapa banyak pasien yang telah melakukan terapi radiasi, tetapi masih ada kemungkinan terjadi kekambuhan ulang?
filter_f = ['recurrence-events']
no_1_f = data_1[(data_1['Iradiasi'] == 'yes') &
              data_1['Class'].isin(filter_f)]
no_1_f
# Out:
#       Umur Golongan Menopause Ukuran Tumor Inv-Nodes Node-Caps  \
# 14   40-49            premeno        25-29       0-2        no
# 23   30-39            premeno        15-19       6-8       yes
# 32   40-49            premeno        30-34       0-2        no
# 56   50-59               ge40        40-44       6-8       yes
# 66   50-59            premeno        25-29       3-5       yes
# 69   30-39            premeno        25-29       6-8       yes
# 86   30-39            premeno        30-34       3-5        no
# 92   60-69               ge40        30-34       0-2        no
# 94   40-49            premeno        20-24       3-5       yes
# 99   60-69               ge40        30-34       3-5       yes
# 100  60-69               ge40        20-24       3-5        no
# 134  60-69               ge40        20-24     24-26       yes
# 140  30-39            premeno        30-34      9-11        no
# 143  40-49            premeno        50-54       0-2        no
# ...

# %%
len(no_1_f)
# Out:
# 30

# %%
#Berapa banyak pasien yang masih berumur 30-39 tahun dengan kondisi kelenjar getah bening telah menembus kapsul dan sekitarnya (node-caps)?
filter_g = ['yes']
no_1_g = data_1[(data_1['Umur'] == '30-39') &
              data_1['Node-Caps'].isin(filter_g)]
no_1_g
# Out:
#       Umur Golongan Menopause Ukuran Tumor Inv-Nodes Node-Caps  \
# 23   30-39            premeno        15-19       6-8       yes
# 69   30-39            premeno        25-29       6-8       yes
# 82   30-39            premeno        25-29       6-8       yes
# 117  30-39            premeno        35-39      9-11       yes
# 146  30-39            premeno        25-29       3-5       yes
# 150  30-39            premeno        20-24       3-5       yes
# 263  30-39            premeno        20-24       3-5       yes
# 274  30-39            premeno        30-34       6-8       yes
#
#      Tingkat Keganasan Payudara Kuadran Payudara Iradiasi  \
# 23                   3     left         left_low      yes
# 69                   3     left        right_low      yes
# 82                   2    right          left_up      yes
# 117                  3     left         left_low       no
# 146                  3     left         left_low      yes
# ...

# %%
len(no_1_g)
# Out:
# 8

# %%
#Berapa banyak pasien yang menopause di atas umur 40 tahun, tetapi tidak melakukan terapi radiasi?
filter_h =['no']
no_1_h = data_1[(data_1['Umur'] > '40') &
              data_1['Iradiasi'].isin(filter_h)]
no_1_h
# Out:
#       Umur Golongan Menopause Ukuran Tumor Inv-Nodes Node-Caps  \
# 0    40-49            premeno        15-19       0-2       yes
# 1    50-59               ge40        15-19       0-2        no
# 2    50-59               ge40        35-39       0-2        no
# 4    40-49            premeno        30-34       3-5       yes
# 6    50-59               ge40        40-44       0-2        no
# ..     ...                ...          ...       ...       ...
# 268  40-49            premeno        35-39       0-2        no
# 270  40-49            premeno        20-24       0-2        no
# 272  50-59               ge40        30-34       6-8       yes
# 275  50-59            premeno        15-19       0-2        no
# 276  50-59               ge40        40-44       0-2        no
#
#      Tingkat Keganasan Payudara Kuadran Payudara Iradiasi  \
# 0                    3    right          left_up       no
# 1                    1    right          central       no
# ...

# %%
len(no_1_h)
# Out:
# 188

# %%
#Berapa banyak pasien dengan ukuran tumor sebesar 50-54 (mm) dengan kelenjar getah bening aksila yang mengandung kanker payudara metastatik sebesar 0-2(mm)?
filter_i =['0-2']
no_1_i = data_1[(data_1['Ukuran Tumor'] == '50-54') &
              data_1['Inv-Nodes'].isin(filter_i)]
no_1_i
# Out:
#       Umur Golongan Menopause Ukuran Tumor Inv-Nodes Node-Caps  \
# 46   50-59            premeno        50-54       0-2       yes
# 54   50-59               ge40        50-54       0-2        no
# 132  60-69               ge40        50-54       0-2        no
# 143  40-49            premeno        50-54       0-2        no
# 155  60-69               ge40        50-54       0-2        no
# 162  40-49            premeno        50-54       0-2        no
# 186  60-69               ge40        50-54       0-2        no
#
#      Tingkat Keganasan Payudara Kuadran Payudara Iradiasi  \
# 46                   2    right          left_up      yes
# 54                   1    right         right_up       no
# 132                  3    right          left_up       no
# 143                  2    right         left_low      yes
# 155                  2     left         left_low       no
# 162                  2     left         left_low       no
# ...

# %%
len(no_1_i)
# Out:
# 7

# %%
#Berapa banyak pasien dengan kelenjar getah bening aksila yang mengandung kanker payudara metastatic sebesar 15-17 (mm) dan dengan kondisi kelenjar getah bening belum/tidak menembus kapsul dan sekitarnya (node-caps)?
filter_j =['no']
no_1_j = data_1[(data_1['Inv-Nodes'] == '15-17') &
              data_1['Node-Caps'].isin(filter_j)]
no_1_j
# Out:
#      Umur Golongan Menopause Ukuran Tumor Inv-Nodes Node-Caps  \
# 53  50-59               ge40        35-39     15-17        no
#
#     Tingkat Keganasan Payudara Kuadran Payudara Iradiasi                 Class
# 53                  3     left         left_low       no  no-recurrence-events

# %%
len(no_1_j)
# Out:
# 1

# %% [markdown]
# # No.2 Penggabungan Data Menggunakan Inner Join, Left Join, Right Join, dan Outer Join (Studi Kasus: Breast Cancer Dataset)

# %% [markdown]
# Implementasikan penggabungan data (merge) menggunakan Inner Join, Left Join,
# Right Join, dan Outer Join menggunakan Python untuk menjawab pertanyaan berikut:

# %%
data2_a = pd.read_csv('./RTM-2 Dataset/2/df1breastquad_odd.csv')
data2_a.head(10)
# Out:
#    PatientID breast-quad
# 0          1     left_up
# 1          3    left_low
# 2          7     left_up
# 3          9   right_low
# 4         11    left_low
# 5         13     central
# 6         17     left_up
# 7         19     left_up
# 8         21     left_up
# 9         23     left_up

# %%
data2_b = pd.read_csv('./RTM-2 Dataset/2/df1tumor_size_odd.csv')
data2_b.head(10)
# Out:
#    PatientID tumor-size
# 0          1      15-19
# 1          3      35-39
# 2          5      30-34
# 3          7      40-44
# 4          9        0-4
# 5         11      25-29
# 6         15      25-29
# 7         17      10-14
# 8         19      40-44
# 9         21      40-44

# %%
data2_c = pd.read_csv('./RTM-2 Dataset/2/df2breastquad_even.csv')
data2_c.head(10)
# Out:
#    PatientID breast-quad
# 0          2     central
# 1          6     left_up
# 2          8     left_up
# 3         10     left_up
# 4         12     left_up
# 5         14     left_up
# 6         16     central
# 7         18     left_up
# 8         22    left_low
# 9         24    left_low

# %%
data2_d = pd.read_csv('./RTM-2 Dataset/2/df2tumor_size_even.csv')
data2_d.head(10)
# Out:
#    PatientID tumor-size
# 0          4      35-39
# 1          6      25-29
# 2          8      10-14
# 3         12      15-19
# 4         14      25-29
# 5         16      20-24
# 6         18      15-19
# 7         22      15-19
# 8         24      15-19
# 9         26      10-14

# %%
df1breastquad = pd.concat([data2_a, data2_c], ignore_index=True)
df1breastquad.head(10)
# Out:
#    PatientID breast-quad
# 0          1     left_up
# 1          3    left_low
# 2          7     left_up
# 3          9   right_low
# 4         11    left_low
# 5         13     central
# 6         17     left_up
# 7         19     left_up
# 8         21     left_up
# 9         23     left_up

# %%
df1tumor_size = pd.concat([data2_b, data2_d], ignore_index=True)
df1tumor_size.head(10)
# Out:
#    PatientID tumor-size
# 0          1      15-19
# 1          3      35-39
# 2          5      30-34
# 3          7      40-44
# 4          9        0-4
# 5         11      25-29
# 6         15      25-29
# 7         17      10-14
# 8         19      40-44
# 9         21      40-44

# %% [markdown]
# a. Berapa banyak record pasien yang memiliki nilai atribut ukuran tumor dan nilai kuadran kanker payudara secara lengkap keduanya ?

# %%
df_inner = df1breastquad.merge(df1tumor_size, how='inner')
df_inner.count()
# Out:
# PatientID      203
# breast-quad    203
# tumor-size     203
# dtype: int64

# %%
df_inner.head(10)
# Out:
#    PatientID breast-quad tumor-size
# 0          1     left_up      15-19
# 1          3    left_low      35-39
# 2          7     left_up      40-44
# 3          9   right_low        0-4
# 4         11    left_low      25-29
# 5         17     left_up      10-14
# 6         19     left_up      40-44
# 7         21     left_up      40-44
# 8         23     left_up      10-14
# 9         27     left_up      10-14

# %% [markdown]
# b. Berapa banyak record pasien yang memiliki nilai atribut ukuran tumor, tetapi tidak memiliki nilai kuadran kanker payudara ? serta berapa banyak record nilai atribut kuadran kanker payudara yang NaN tersebut ?

# %%
no_2_b = df1breastquad.merge(df1tumor_size, how='right')
no_2_b.count()
# Out:
# PatientID      238
# breast-quad    203
# tumor-size     238
# dtype: int64

# %%
no_2_b.head(10)
# Out:
#    PatientID breast-quad tumor-size
# 0          1     left_up      15-19
# 1          3    left_low      35-39
# 2          7     left_up      40-44
# 3          9   right_low        0-4
# 4         11    left_low      25-29
# 5         17     left_up      10-14
# 6         19     left_up      40-44
# 7         21     left_up      40-44
# 8         23     left_up      10-14
# 9         27     left_up      10-14

# %%
no_2_b.isnull().sum()
# Out:
# PatientID       0
# breast-quad    35
# tumor-size      0
# dtype: int64

# %% [markdown]
# c. Berapa banyak record pasien yang tidak memiliki nilai atribut ukuran tumor, tetapi memiliki nilai kuadran kanker payudara ? serta berapa banyak record nilai atribut ukuran tumor yang NaN tersebut ?

# %%
no_2_c = df1breastquad.merge(df1tumor_size, how='left')
no_2_c.count()
# Out:
# PatientID      237
# breast-quad    237
# tumor-size     203
# dtype: int64

# %%
no_2_c.head(10)
# Out:
#    PatientID breast-quad tumor-size
# 0          1     left_up      15-19
# 1          3    left_low      35-39
# 2          7     left_up      40-44
# 3          9   right_low        0-4
# 4         11    left_low      25-29
# 5         13     central        NaN
# 6         17     left_up      10-14
# 7         19     left_up      40-44
# 8         21     left_up      40-44
# 9         23     left_up      10-14

# %%
no_2_c.isnull().sum()
# Out:
# PatientID       0
# breast-quad     0
# tumor-size     34
# dtype: int64

# %% [markdown]
# d. Jika menggunakan Outer Join, Berapa banyak record pasien yang NaN pada masing-masing atribut, baik pada atribut ukuran tumor maupun kuadran kanker payudara?

# %%
df_outer = df1breastquad.merge(df1tumor_size, how='outer')
df_outer.count()
# Out:
# PatientID      272
# breast-quad    237
# tumor-size     238
# dtype: int64

# %%
df_outer.head(10)
# Out:
#    PatientID breast-quad tumor-size
# 0          1     left_up      15-19
# 1          3    left_low      35-39
# 2          7     left_up      40-44
# 3          9   right_low        0-4
# 4         11    left_low      25-29
# 5         13     central        NaN
# 6         17     left_up      10-14
# 7         19     left_up      40-44
# 8         21     left_up      40-44
# 9         23     left_up      10-14

# %%
df_outer.isnull().sum()
# Out:
# PatientID       0
# breast-quad    35
# tumor-size     34
# dtype: int64

# %% [markdown]
# # No.3 Transformasi Data: Duplikasi Data, Missing Values, dan Imputasi Missing Values

# %%
data3 = pd.read_csv('./RTM-2 Dataset/3/Hepatitis.csv')
data3
# Out:
#        #  Age  Sex  Steroid  Antivirals  Fatique  Malaise  Anorexia  \
# 0      1   30    2      1.0           2      2.0      2.0       2.0
# 1      2   50    1      1.0           2      1.0      2.0       2.0
# 2      3   78    1      2.0           2      1.0      2.0       2.0
# 3      4   31    1      NaN           1      2.0      2.0       2.0
# 4      5   34    1      2.0           2      2.0      2.0       2.0
# ..   ...  ...  ...      ...         ...      ...      ...       ...
# 150  151   46    1      2.0           2      1.0      1.0       1.0
# 151  152   44    1      2.0           2      1.0      2.0       2.0
# 152  153   61    1      1.0           2      1.0      1.0       2.0
# 153  154   53    2      1.0           2      1.0      2.0       2.0
# 154  155   43    1      2.0           2      1.0      2.0       2.0
#
#      Liver Big  Liver Firm  ...  Speiders  Ascites  Varices  Bilirubin  \
# 0          1.0         2.0  ...       2.0      2.0      2.0        1.0
# ...

# %% [markdown]
# b1. Lakukan pemeriksaan apakah terdapat duplikasi data (row) pada dataset hepatitis

# %%
data3.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 150    False
# 151    False
# 152    False
# 153    False
# 154    False
# Length: 155, dtype: bool

# %%
data3.duplicated().sum()
# Out:
# 0

# %% [markdown]
# b2. Lakukan analisis deskriptif berapa banyak atribut yang memiliki missing values

# %%
data3.isnull()
# Out:
#          #    Age    Sex  Steroid  Antivirals  Fatique  Malaise  Anorexia  \
# 0    False  False  False    False       False    False    False     False
# 1    False  False  False    False       False    False    False     False
# 2    False  False  False    False       False    False    False     False
# 3    False  False  False     True       False    False    False     False
# 4    False  False  False    False       False    False    False     False
# ..     ...    ...    ...      ...         ...      ...      ...       ...
# 150  False  False  False    False       False    False    False     False
# 151  False  False  False    False       False    False    False     False
# 152  False  False  False    False       False    False    False     False
# 153  False  False  False    False       False    False    False     False
# 154  False  False  False    False       False    False    False     False
#
#      Liver Big  Liver Firm  ...  Speiders  Ascites  Varices  Bilirubin  \
# ...

# %%
data3.isnull().sum()
# Out:
# #                   0
# Age                 0
# Sex                 0
# Steroid             1
# Antivirals          0
# Fatique             1
# Malaise             1
# Anorexia            1
# Liver Big          10
# Liver Firm         11
# Spleen Palpable     5
# Speiders            5
# Ascites             5
# Varices             5
# Bilirubin           6
# Alk Phosphate      29
# SGOT                4
# Albumin            16
# Protime            67
# Histology           0
# CLASS               0
# dtype: int64

# %% [markdown]
# b3. Lakukan inputasi missing values dengan berbagai teknik yang efektif dan baik untuk mengisi atribut-atribut yang NaN, misalnya menggunakan mean, median, modus, clustering, regression, maupun metode taksiran dan prediksi lainnya

# %%
data3.dtypes
# Out:
# #                    int64
# Age                  int64
# Sex                  int64
# Steroid            float64
# Antivirals           int64
# Fatique            float64
# Malaise            float64
# Anorexia           float64
# Liver Big          float64
# Liver Firm         float64
# Spleen Palpable    float64
# Speiders           float64
# Ascites            float64
# Varices            float64
# Bilirubin          float64
# Alk Phosphate      float64
# SGOT               float64
# Albumin            float64
# Protime            float64
# Histology            int64
# CLASS                int64
# dtype: object

# %%
import statistics
import numpy as np

# %%
modus = statistics.mode(data3["Steroid"])
data3["Steroid"] = data3["Steroid"].replace(np.nan, modus)
data3["Steroid"]
# Out:
# 0      1.0
# 1      1.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 150    2.0
# 151    2.0
# 152    1.0
# 153    1.0
# 154    2.0
# Name: Steroid, Length: 155, dtype: float64

# %%
modus = statistics.mode(data3["Fatique"])
data3["Fatique"] = data3["Fatique"].replace(np.nan, modus)
data3["Fatique"]
# Out:
# 0      2.0
# 1      1.0
# 2      1.0
# 3      2.0
# 4      2.0
#       ...
# 150    1.0
# 151    1.0
# 152    1.0
# 153    1.0
# 154    1.0
# Name: Fatique, Length: 155, dtype: float64

# %%
modus = statistics.mode(data3["Malaise"])
data3["Malaise"] = data3["Malaise"].replace(np.nan, modus)
data3["Malaise"]
# Out:
# 0      2.0
# 1      2.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 150    1.0
# 151    2.0
# 152    1.0
# 153    2.0
# 154    2.0
# Name: Malaise, Length: 155, dtype: float64

# %%
modus = statistics.mode(data3["Anorexia"])
data3["Anorexia"] = data3["Anorexia"].replace(np.nan, modus)
data3["Anorexia"]
# Out:
# 0      2.0
# 1      2.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 150    1.0
# 151    2.0
# 152    2.0
# 153    2.0
# 154    2.0
# Name: Anorexia, Length: 155, dtype: float64

# %%
modus = statistics.mode(data3["Liver Big"])
data3["Liver Big"] = data3["Liver Big"].replace(np.nan, modus)
data3["Liver Big"]
# Out:
# 0      1.0
# 1      1.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 150    2.0
# 151    2.0
# 152    1.0
# 153    2.0
# 154    2.0
# Name: Liver Big, Length: 155, dtype: float64

# %%
modus = statistics.mode(data3["Liver Firm"])
data3["Liver Firm"] = data3["Liver Firm"].replace(np.nan, modus)
data3["Liver Firm"]
# Out:
# 0      2.0
# 1      2.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 150    2.0
# 151    1.0
# 152    1.0
# 153    2.0
# 154    2.0
# Name: Liver Firm, Length: 155, dtype: float64

# %%
modus = statistics.mode(data3["Spleen Palpable"])
data3["Spleen Palpable"] = data3["Spleen Palpable"].replace(np.nan, modus)
data3["Spleen Palpable"]
# Out:
# 0      2.0
# 1      2.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 150    2.0
# 151    2.0
# 152    2.0
# 153    1.0
# 154    1.0
# Name: Spleen Palpable, Length: 155, dtype: float64

# %%
modus = statistics.mode(data3["Speiders"])
data3["Speiders"] = data3["Speiders"].replace(np.nan, modus)
data3["Speiders"]
# Out:
# 0      2.0
# 1      2.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 150    1.0
# 151    2.0
# 152    1.0
# 153    1.0
# 154    1.0
# Name: Speiders, Length: 155, dtype: float64

# %%
modus = statistics.mode(data3["Ascites"])
data3["Ascites"] = data3["Ascites"].replace(np.nan, modus)
data3["Ascites"]
# Out:
# 0      2.0
# 1      2.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 150    1.0
# 151    2.0
# 152    2.0
# 153    2.0
# 154    1.0
# Name: Ascites, Length: 155, dtype: float64

# %%
modus = statistics.mode(data3["Varices"])
data3["Varices"] = data3["Varices"].replace(np.nan, modus)
data3["Varices"]
# Out:
# 0      2.0
# 1      2.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 150    1.0
# 151    2.0
# 152    2.0
# 153    1.0
# 154    2.0
# Name: Varices, Length: 155, dtype: float64

# %%
mean = data3["Bilirubin"].mean()
data3["Bilirubin"] = data3["Bilirubin"].replace(np.nan, mean)
data3["Bilirubin"]
# Out:
# 0      1.0
# 1      0.9
# 2      0.7
# 3      0.7
# 4      1.0
#       ...
# 150    7.6
# 151    0.9
# 152    0.8
# 153    1.5
# 154    1.2
# Name: Bilirubin, Length: 155, dtype: float64

# %%
mean = data3["Alk Phosphate"].mean()
data3["Alk Phosphate"] = data3["Alk Phosphate"].replace(np.nan, mean)
data3["Alk Phosphate"]
# Out:
# 0       85.000000
# 1      135.000000
# 2       96.000000
# 3       46.000000
# 4      105.325397
#           ...
# 150    105.325397
# 151    126.000000
# 152     75.000000
# 153     81.000000
# 154    100.000000
# Name: Alk Phosphate, Length: 155, dtype: float64

# %%
mean = data3["SGOT"].mean()
data3["SGOT"] = data3["SGOT"].replace(np.nan, mean)
data3["SGOT"]
# Out:
# 0       18.0
# 1       42.0
# 2       32.0
# 3       52.0
# 4      200.0
#        ...
# 150    242.0
# 151    142.0
# 152     20.0
# 153     19.0
# 154     19.0
# Name: SGOT, Length: 155, dtype: float64

# %%
mean = data3["Albumin"].mean()
data3["Albumin"] = data3["Albumin"].replace(np.nan, mean)
data3["Albumin"]
# Out:
# 0      4.0
# 1      3.5
# 2      4.0
# 3      4.0
# 4      4.0
#       ...
# 150    3.3
# 151    4.3
# 152    4.1
# 153    4.1
# 154    3.1
# Name: Albumin, Length: 155, dtype: float64

# %%
mean = data3["Protime"].mean()
data3["Protime"] = data3["Protime"].replace(np.nan, mean)
data3["Protime"]
# Out:
# 0      61.852273
# 1      61.852273
# 2      61.852273
# 3      80.000000
# 4      61.852273
#          ...
# 150    50.000000
# 151    61.852273
# 152    61.852273
# 153    48.000000
# 154    42.000000
# Name: Protime, Length: 155, dtype: float64

# %%
data3.isnull().sum()
# Out:
# #                  0
# Age                0
# Sex                0
# Steroid            0
# Antivirals         0
# Fatique            0
# Malaise            0
# Anorexia           0
# Liver Big          0
# Liver Firm         0
# Spleen Palpable    0
# Speiders           0
# Ascites            0
# Varices            0
# Bilirubin          0
# Alk Phosphate      0
# SGOT               0
# Albumin            0
# Protime            0
# Histology          0
# CLASS              0
# dtype: int64

# %% [markdown]
# # No.4 Deteksi Outlier: InterQuartile Range dan BoxPlot

# %%
data4 = pd.read_csv('./RTM-2 Dataset/4/ATM-Transaction.csv')
data4
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 0          Big Street ATM         01/01/11                 50
# 1          Mount Road ATM         01/01/11                253
# 2             Airport ATM         01/01/11                 98
# 3            KK Nagar ATM         01/01/11                265
# 4      Christ College ATM         01/01/11                 74
# ...                   ...              ...                ...
# 11584      Big Street ATM         29/09/17                137
# 11585      Mount Road ATM         29/09/17                 79
# 11586         Airport ATM         29/09/17                117
# 11587        KK Nagar ATM         29/09/17                 76
# 11588  Christ College ATM         29/09/17                143
#
#        Total amount Withdrawn (Rupee)  Total amount Withdrawn (Rupiah)  \
# 0                              123800                         23136982
# 1                              767900                        143512831
# ...

# %%
data4.describe()
# Out:
#        No Of Withdrawals  Total amount Withdrawn (Rupee)  \
# count       11589.000000                    1.158900e+04
# mean          123.341099                    5.223059e+05
# std            67.315288                    3.248167e+05
# min             1.000000                    1.000000e+02
# 25%            79.000000                    3.057000e+05
# 50%           115.000000                    4.700000e+05
# 75%           158.000000                    6.716000e+05
# max           491.000000                    2.549800e+06
#
#        Total amount Withdrawn (Rupiah)
# count                     1.158900e+04
# mean                      9.761375e+07
# std                       6.070499e+07
# min                       1.868900e+04
# 25%                       5.713227e+07
# 50%                       8.783830e+07
# 75%                       1.255153e+08
# max                       4.765321e+08

# %%
data4.dtypes
# Out:
# ATM Name                           object
# Transaction Date                   object
# No Of Withdrawals                   int64
# Total amount Withdrawn (Rupee)      int64
# Total amount Withdrawn (Rupiah)     int64
# Weekday                            object
# dtype: object

# %%
data4.isnull().sum()
# Out:
# ATM Name                           0
# Transaction Date                   0
# No Of Withdrawals                  0
# Total amount Withdrawn (Rupee)     0
# Total amount Withdrawn (Rupiah)    0
# Weekday                            0
# dtype: int64

# %% [markdown]
# a. Bank mana yang teramai dan tersepi bagi nasabah untuk melakukan penarikan uang?

# %% [markdown]
# ### Teramai

# %%
data4.sort_values("Total amount Withdrawn (Rupiah)", ascending=False, inplace=True)
data4
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 6772         KK Nagar ATM         01/10/14                480
# 4309         KK Nagar ATM         13/05/13                444
# 6168         KK Nagar ATM         02/06/14                426
# 3348         KK Nagar ATM         01/11/12                410
# 4423         KK Nagar ATM         05/06/13                404
# ...                   ...              ...                ...
# 10411  Christ College ATM         28/11/16                  1
# 10656        KK Nagar ATM         05/03/17                  1
# 10368        KK Nagar ATM         14/11/16                  1
# 10379         Airport ATM         19/11/16                  1
# 8665          Airport ATM         19/10/15                  1
#
#        Total amount Withdrawn (Rupee)  Total amount Withdrawn (Rupiah)  \
# 6772                          2549800                        476532122
# 4309                          2459200                        459599888
# ...

# %% [markdown]
# ### Tersepi

# %%
data4.sort_values("Total amount Withdrawn (Rupiah)", ascending=True, inplace=True)
data4
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 8665      Airport ATM         19/10/15                  1
# 8656      Airport ATM         17/10/15                  1
# 10421  Mount Road ATM         01/12/16                  1
# 10024    KK Nagar ATM         26/08/16                  1
# 10379     Airport ATM         19/11/16                  1
# ...               ...              ...                ...
# 4423     KK Nagar ATM         05/06/13                404
# 3348     KK Nagar ATM         01/11/12                410
# 6168     KK Nagar ATM         02/06/14                426
# 4309     KK Nagar ATM         13/05/13                444
# 6772     KK Nagar ATM         01/10/14                480
#
#        Total amount Withdrawn (Rupee)  Total amount Withdrawn (Rupiah)  \
# 8665                              100                            18689
# 8656                              100                            18689
# ...

# %% [markdown]
# Pada hari apa ATM paling sering dan pada hari apa yang paling jarang dikunjungi oleh nasabah untuk melakukan penarikan uang?

# %%
data4['Weekday'].value_counts()
# Out:
# SUNDAY       2177
# SATURDAY     1131
# TUESDAY       989
# WEDNESDAY     947
# MONDAY        945
# THURSDAY      903
# FRIDAY        902
# Saturday      518
# Thursday      517
# Wednesday     515
# Tuesday       513
# Monday        513
# Friday        510
# Sunday        509
# Name: Weekday, dtype: int64

# %% [markdown]
# Karena terdapat beberapa hari dengan huruf kapital, sehingga terbaca berbeda. Kita lakukan preprocessing data

# %%
data4['Weekday'] = data4['Weekday'].apply(lambda x: x.lower())
data4['Weekday']
# Out:
# 8665        monday
# 8656      saturday
# 10421     thursday
# 10024       friday
# 10379     saturday
#            ...
# 4423     wednesday
# 3348        sunday
# 6168        monday
# 4309        monday
# 6772     wednesday
# Name: Weekday, Length: 11589, dtype: object

# %%
data4
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 8665      Airport ATM         19/10/15                  1
# 8656      Airport ATM         17/10/15                  1
# 10421  Mount Road ATM         01/12/16                  1
# 10024    KK Nagar ATM         26/08/16                  1
# 10379     Airport ATM         19/11/16                  1
# ...               ...              ...                ...
# 4423     KK Nagar ATM         05/06/13                404
# 3348     KK Nagar ATM         01/11/12                410
# 6168     KK Nagar ATM         02/06/14                426
# 4309     KK Nagar ATM         13/05/13                444
# 6772     KK Nagar ATM         01/10/14                480
#
#        Total amount Withdrawn (Rupee)  Total amount Withdrawn (Rupiah)  \
# 8665                              100                            18689
# 8656                              100                            18689
# ...

# %%
data4['Weekday'].value_counts()
# Out:
# sunday       2686
# saturday     1649
# tuesday      1502
# wednesday    1462
# monday       1458
# thursday     1420
# friday       1412
# Name: Weekday, dtype: int64

# %% [markdown]
# Lakukan deteksi outlier untuk melihat potensi adanya fraud berdasarkan atribut Total amount Withdrawn (in Rupiah) pada dataset ATM Transaction menggunakan metode InterQuartileRange dan visualisasikan menggunakan BoxPlot serta sebutkan nama No Of Withdrawals dan nama ATM-nya yang terdeteksi fraud.

# %%
Q1 = np.percentile(data4['Total amount Withdrawn (Rupiah)'], 25, interpolation = 'midpoint')
  
# Third quartile (Q3)
Q3 = np.percentile(data4['Total amount Withdrawn (Rupiah)'], 75, interpolation = 'midpoint')
  
# Interquaritle range (IQR)
IQR = Q3 - Q1
  
print(IQR)
# Out:
# 68383051.0
# <ipython-input-129-0dfdc4882ee6>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(data4['Total amount Withdrawn (Rupiah)'], 25, interpolation = 'midpoint')
# <ipython-input-129-0dfdc4882ee6>:4: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(data4['Total amount Withdrawn (Rupiah)'], 75, interpolation = 'midpoint')

# %%
min_IQR = Q1 - 1.5 * IQR
max_IQR = Q3 + 1.5 * IQR

print('IQR minimum = ', min_IQR)
print('IQR maksimum = ', max_IQR)
# Out:
# IQR minimum =  -45442303.5
# IQR maksimum =  228089900.5

# %%
nilai_min = np.min(data4['Total amount Withdrawn (Rupiah)'])
nilai_max = np.max(data4['Total amount Withdrawn (Rupiah)'])

print('Nilai minimum data = ', nilai_min)
print('Nilai maksimum data = ', nilai_max)
# Out:
# Nilai minimum data =  18689
# Nilai maksimum data =  476532122

# %%
if (nilai_min < min_IQR):
    print('Ditemukan low outlier!')
else:
    print('Tidak ditemukan low outlier!')  

if (nilai_max > max_IQR):
    print('Ditemukan high outlier!')
else:
    print('Tidak ditemukan high outlier!')
# Out:
# Tidak ditemukan low outlier!
# Ditemukan high outlier!

# %%
low_out = []
high_out = []

for i in data4['Total amount Withdrawn (Rupiah)']:
    if (i < min_IQR):
        low_out.append(i)
    if (i > max_IQR):
        high_out.append(i)

print('Low outlier : ', low_out)
print('High outlier : ', high_out)
# Out:
# Low outlier :  []
# ...

# %%
plt.boxplot(data4['Total amount Withdrawn (Rupiah)'], showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26a2f4e1c70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26a2f4ed370>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26a2f4e1970>],
#  'medians': [<matplotlib.lines.Line2D at 0x26a2f4eda30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26a2f4f90d0>],
#  'means': [<matplotlib.lines.Line2D at 0x26a2f4edd30>]}
